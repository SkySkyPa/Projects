# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Mcdonalds.csv', index_col='Fiscal Year / Year')
df
# Out:
#                     McDonald's Revenue($-B)  Growth Rate(%)   Q1   Q2   Q3  \
# Fiscal Year / Year
# 1999                                   13.3               1  NaN  NaN  NaN
# 2000                                   14.2               7  NaN  NaN  NaN
# 2001                                   14.9               4  NaN  NaN  NaN
# 2002                                   15.4               4  NaN  NaN  NaN
# 2003                                   17.1              11  3.8  4.3  4.5
# 2004                                   18.6               8  4.4  4.7  4.9
# 2005                                   19.1               3  4.8  5.1  5.3
# 2006                                   20.9               9  4.9  5.4  5.5
# 2007                                   22.8               9  5.3  5.8  5.9
# 2008                                   23.5               3  5.6  6.1  6.3
# 2009                                   22.7              -3  5.1  5.6  6.0
# ...

# %% [markdown]
# q1,2,3,4 is quarters of income

# %%
df.shape
# Out:
# (24, 6)

# %%
df.isnull().values.any() # determine if value in series missing
# Out:
# True

# %%
df.isnull().sum() # how many missing values
# Out:
# McDonald's Revenue($-B)    0
# Growth Rate(%)             0
# Q1                         4
# Q2                         4
# Q3                         4
# Q4                         3
# dtype: int64

# %%
df = df.dropna()
df.isnull().values.any() # determine if value in series missing
# Out:
# False

# %%
df.dtypes
# Out:
# McDonald's Revenue($-B)    float64
# Growth Rate(%)               int64
# Q1                         float64
# Q2                         float64
# Q3                         float64
# Q4                         float64
# dtype: object

# %%
y = df['Growth Rate(%)'] # target vrb
X = df[['McDonald\'s Revenue($-B)', 'Q1', 'Q2', 'Q3', 'Q4']] # features

# %%
# test and train dataset

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb
import numpy as np

data = pd.read_csv('Mcdonalds.csv')
data = data.dropna()

mask = np.triu(np.ones_like(data.corr()))

dataplot = sb.heatmap(data.corr(), cmap="YlGnBu", annot=True, mask=mask)

mp.show()

# %%
# Correlation between variables "crest",

cor = df.corr()
clrmap = sns.color_palette("YlOrBr", as_cmap=True)

sns.heatmap(cor,xticklabels=cor.columns,yticklabels=cor.columns, cmap=clrmap, annot=True)
sns.set(rc={'figure.figsize':(24,8)},font_scale=1.2)

# %% [markdown]
# MC Rev - Q1, Q2, Q3, Q4
# Q1 - Q3
# Q2 - Q3
# Q3 - Q4

# %%
pl = sns.kdeplot(df['Q1'], fill=True, color='y')
pl = sns.kdeplot(df['Q2'], fill=True, color='r')
pl = sns.kdeplot(df['Q3'], fill=True, color='grey')
pl = sns.kdeplot(df['Q4'], fill=True, color='b')

# %%
pl = sns.kdeplot(df['Q1'], fill=True, color='y')
pl = sns.kdeplot(df['Q3'], fill=True, color='grey')

# %%
pl = sns.kdeplot(df['Q2'], fill=True, color='r')
pl = sns.kdeplot(df['Q3'], fill=True, color='grey')

# %%
pl = sns.kdeplot(df['Q3'], fill=True, color='grey')
pl = sns.kdeplot(df['Q4'], fill=True, color='b')

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression()

# %%
predictedDis = regr.predict([[24.3, 4.5, 3.2, 4.7, 2.8]])
print(predictedDis)
# Out:
# [15.27925978]
# /Users/aristarcharistarchovich/DataspellProjects/newPython/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
