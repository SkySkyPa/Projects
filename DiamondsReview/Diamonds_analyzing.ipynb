# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv("diamonds.csv")

df.head(20)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...

# %%
print("Value in series missing: ",df.isnull().values.any()) # determine if value in series missing
# Out:
# Value in series missing:  False

# %%
df.dropna()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [50000 rows x 10 columns]

# %%
print(df.isnull().sum()) # how many missing values
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df['color'] = pd.factorize(df.color)[0]

# %%
import seaborn as sns
# Correlation between variables

cor = df.corr()
clrmap = sns.diverging_palette(250, 200, s=75, as_cmap=True)

sns.heatmap(cor,xticklabels=cor.columns,yticklabels=cor.columns, cmap=clrmap, annot=True)
sns.set(rc={'figure.figsize':(20,10)},font_scale=2.4)
# Out:
# /var/folders/lk/p4rmv9cx45d_zk5h2j11pwl40000gn/T/ipykernel_50543/144282998.py:4: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# x - carat: 0.98
# y - carat: 0.95
# z - carat: 0.95
#
# price - carat: 0.92

# %%
# sns.pairplot(rows, diag_kind='kde')

# %%
# fig = px.pie(rows, values='carat', names='clarity', # title='Clarity to carat review')
# fig.show()

# %%
fig = px.bar(df, x="color", y="price", color = 'cut',title="color to price review")
fig.show()
# Out:
# <div>                            <div id="8da46138-0b08-40ca-815c-10af56f22599" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8da46138-0b08-40ca-815c-10af56f22599")) {                    Plotly.newPlot(                        "8da46138-0b08-40ca-815c-10af56f22599",                        [{"alignmentgroup":"True","hovertemplate":"cut=Ideal<br>color=%{x}<br>price=%{y}<extra></extra>","legendgroup":"Ideal","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Ideal","offsetgroup":"Ideal","orientation":"v","showlegend":true,"textposition":"auto","x":[0,2,2,1,1,1,2,5,1,1,6,1,0,1,0,5,1,5,1,4,0,4,0,4,4,5,0,4,0,3,6,3,5,0,6,4,6,5,4,5,4,6,0,0,0,0,5,5,0,0,4,0,4,5,5,3,3,5,6,4,4,6,1,4,0,5,5,4,0,0,4,1,3,4,6,5,3,3,1,4,6,5,1,5,4,4,3,4,5,0,6,4,3,6,6,6,0,5,4
# ...
